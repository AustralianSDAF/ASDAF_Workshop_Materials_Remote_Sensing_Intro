# %% [markdown]
# ##

# %% [markdown]
# # Introduction and Refresher

# %% [markdown]
# A small (re)introduction to python for those with less experience.
# This is by no means a propper introduction, but a fast paced re-introduction, as this course has been designed for those with some basic pre-existing python.
#
# Python let's us automate many tasks, including calculations, being able to store results.

# %% [markdown]
# ## ❓ Questions
# - What is a Jupyter Notebook
# - Why use Python?
# - What is abstraction?
#
# ## ❗ Objectives
# - Understand what a notebook is
# - be able to read basic python syntax
# - Understand basic datatype like `int`, `list`, etc.
# - Understand why abstraction is important
# - Understand on a high level what a function and a class are

# %% [markdown]
# # ⚡ Jupyter basics
# Before we get into Python, let's refresh the basics of Jupyter
#
# ## Why Jupyter?
# Jupyter allows you to run python and visualise it all in one place. In some circumstances it will be btter to use a script (a '.py' file), but for exploratory analysis jupyter is usually the best choice.
#
# ## Cells
# A jupyter notebook (the file you're currently in) is divided into 'Cells'. Each of these cells is either a "code" or "markdown" cell.
# You can activate a cell by clicking on the body of it, and you should see a highlight on the left-hand side telling you it is the current active cell.
# A new cell can either by created below the current one by clicking on the "+code" or "+markdown" buttons at the top.
# A cell can then be deleted either with the button on the top-left of the cell, or if activated outside of edit mode (click just to the left of the cell) by pressing `d` twice in succession.

# %% [markdown]
# ## Markdown Cells
# [Markdown](https://en.wikipedia.org/wiki/Markdown) is a type of [markup language](https://en.wikipedia.org/wiki/Markup_language). Markdown is designed to easily format plain-text notes in a human readable form that is then able to rendered to something slightly fancier.
# If you click the "+ Markdown" button at the top, a new markdown cell will be created.
# You can also double click on a text box to edit it. To render a markdown Cell as text, hold `shift` and the press `enter`, or click the tick in the top-right of the cell.
# Markdown is very useful to structure a notebook, and especially great when sharing notebooks with others. An example of how markdown looks is below:
#
# ---
# ```markdown
# # A title
# ## A subtitle
# Some text
# - A dot-point list item
# - The next dot-point item
#
# ### Another sub-subtitle
# 1. A numbered list
# 2. Another numbered list item
#
# > Quoted text
#
# Some text with a [hyperlink to a website](https://google.com). The website URL is not rendered.
#
# Some code `a = 3 + 4`
# ```
# If you double click on this text, you'll see how the markdown looks. Hold `shift`, then press `enter` to re-render it.
#
# ---

# %% [markdown]
# ## Code Cells
# The other type of cell jupyter has is a 'code' cell. These cells will run any text within them based on the currently active 'kernel', which will 'intepret' the cells.
# The name Jupyter is a combination of `JUlia`, `PYthon`, and `R`, the three core languages supported, but it can be extended to support other languages.
# This course will only use python.
#
# You can make a new code cell with either the "+Code" button at the top, or clicking just to the left of a cell and press "b" for a cell below", or "a" for a cell above the current cell.

# %% [markdown]
# ## ⚡ Basic operations and readability
# Below, we use a 'variable' `a` to store the result of `3+4`. Then we call the print function on the variable `a`

# %%
a = 3 + 4
print(a)

# %% [markdown]
# We can also add comments to our code with the `#` symbol. These are not run.

# %%
# An example of a comment.
# Comments help our code become more understandbale by humans. 
# On the flip-side, too many comments can make it harder to read.

# Try to use comments only when they're needed, e.g. citing a paper or explaining *why* something is coded the way it is

print(4 + 5)
print(3 + 4) # We can also put comments on a line. Nothing after the hash is execututed
print('Comments are great!') # The next lines run normally.
# Out:
# 9
# 7
# Comments are great!

# %%
# Write some of your own equations here to evaluate!

# %% [markdown]
# ### Coding Style
# Just because you can, doesnt mean you should.
#
# Python lets you code in a variety of ways, but sometimes this can make it harder to read.
# Compare the two ways of creating a variable below.
#
# The second way is should be a litter easier to tell what is happening in the seoncd cell, by dividing it into smaller sections, naming things better, and spacing appropriatly.

# %%
var_1=3*4/(4+5*(6-3)/3+3*4)-3*4/12+15
print("The first variable is", var_1)
# Out:
# The first variable is 14.571428571428571

# %%
heat = 3 * 4 
time = (4 + 5*(6 - 3)/3 + 3*4)
extra_power = -3 * 4 / 12 + 15

total_power = (heat / time) + extra_power
print("The second variable is", total_power)
# Out:
# The second variable is 14.571428571428571

# %% [markdown]
# To try to codify good ways of programming, people create what are known as 'style guides', to dictate standard ways of coding to improve readability.
# The general Style guide for Python is [Python Ehancement Proposal 7 (a.k.a. "PEP 7")](https://peps.python.org/pep-0007/).  The key thing to note is right at the start:
# > Note, rules are there to be broken. Two good reasons to break a particular rule:
# > - When applying the rule would make the code less readable, even for someone who is used to reading code that follows the rules.
# > - To be consistent with surrounding code that also breaks it (maybe for historic reasons) – although this is also an opportunity to clean up someone else’s mess
#
# Other than that, the key to readable code is to name things properly.
# This is easier than it sounds; a recurring joke is that:
# > There are two unsolved problems in programming:
# > - Naming things
# > - Efficiently manging projects
# > - Off by one errors
#
# We'll leave it to your best judgment on how to name things properly for the domain you work in.

# %% [markdown]
# # Data Types

# %% [markdown]
# We can also store other 'types' of things in python. Some intrinsic (coming with default python) types include:
# - `int`, Integers (whole numbers)
# - `float`, decimal numbers ('floating point' as it internally stores a number using scientific notation. Can store large numbers, but loses accuracy)
# - `str`, strings (collections of characters. NB: The string of a number if different to the integer or float representation of that number)
# - `tuple`, A tuple is a grouping of objects that is [immutable](https://en.wikipedia.org/wiki/Immutable_object)
# - `list`, A list is a grouping of objects that is mutable
# - `function` a function can be called, usually with parameters that it can operate on.
# and many others.

# %%
# Type of a number
print('Type of 3 is', type(3))
# Out:
# Type of 3 is <class 'int'>
# The type of a string is <class 'str'>
#
# Type of a function is <class 'function'>
# The type of the result of this function in particular is <class 'float'>

# %%
# Type of a string
b = 'example string'
print('The type of a string is', type(b))

# %%
def example_function(x):
    """ An example function for testing types"""
    return x**2 / 2

# %%
# Type of a function and the result of a function
print('Type of a function is', type(example_function))
print('The type of the result of this function in particular is', type(example_function(3.2)))
# Out:
# Type of a function is <class 'function'>
# The type of the result of this function in particular is <class 'float'>

# %% [markdown]
# ## 🔥 Question - Implicit Types and Type conversions
# Compelte the following at your own pace
# - Set the variable `a = 3`
# - What is the type of `a * a`?
# - What is the type of `a / a`
# - Repeat this with `a = 3.0`
# - If these are the same or different, why?

# %%
# Enter question here
a = 3
# Start from below!

# %% [markdown]
# ## Tuples and Lists

# %%
# Create a tuple

# Change the 2nd element of a tuple

# %%
# Create a list

# Change the 2nd element of a list

# %% [markdown]
# ## Dictionaries
# Dictionaries are a useful way of storing information with `keys` and `values`.
# Rather than a list, which is indexed with numbers, in a dictionary, a `key` will give you the associated `value`.
# Sometimes you may hear dictionaries called 'hash maps' - they are the same thing.
#
# In python, dictionaries are defined with curly brackets `{}`

# %%
# Create a dictionary

# %%
# Use the dictionary!

# %% [markdown]
# # Unpacking lists and dictionaries
# The `*` (unpack list) and `**` (unpack pairs) operators allow us to unpack lists and dictionaries into other lists or functions.
# We will make use of these a fair bit throughout this course

# %%
# Create a list, and then create a new list from the unpacked list
a = [1, 2, 3]
b = [6, *a, 7]
print(b)
# Out:
# [6, 1, 2, 3, 7]

# %% [markdown]
# # 🔔 Why not just use a calculator or excel?
# So far we've not done very much that cant also easily be done in excel or a calculator, so why learn programming?
#
# Porgramming languages introduce three important things that excel/calculators do not do or dont do well all at together:
# - Control Flow - Change what to do based on conditions
# - Iteration - Do something multiple times with minimal effort
# - Abstraction - 'Abtract' away a concept to re-use with minimal effort

# %% [markdown]
# ### Control Flow
# Using `if`, `elif`, and `else` statements, we can direct the flow of a program based on inputs.
#
# More advanced usage can include the ["Ask Forgiveness rather than Permission"](https://realpython.com/python-lbyl-vs-eafp/) paradigm with `try`, `except`, and `raise`.
#
# An example is below.
# - Read the code, and come up with an explanation of what it is doing and why based on the english interpreation of the words used.
# - Change the `flow_rate_mL` variable a few times. Try values like `-1`, `20`, `100`, etc.
# - Does the output match what you'd expect?

# %%
flow_rate_mL = 45 # In practice this value might come from a sensor and/or the output of another part of the program

# Program description:
# Check if flow rate is in reasonable bounds
# Check if flow rate is beyond an overflow threshold
# Otherwise an overflow is not detected !
# Print out if an overflow is detected
if (flow_rate_mL < 0) or (flow_rate_mL > 1e10): 
    raise ValueError("Flow rate outside rational bounds!")
elif (flow_rate_mL > 30):
    overflow_detected = True
else:
    overflow_detected = False

print(overflow_detected)
# Out:
# True

# %%
# Try, except example.
# Squaring a string?
total_money = '3'
try:
    total_money = total_money **2
except TypeError as e:
    print("Not expecting something that isnt a number!")
    raise e # Raise the error anyway
# Out:
# Not expecting something that isnt a number!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       6 except TypeError as e:
#       7     print("Not expecting something that isnt a number!")
# ----> 8     raise e # Raise the error anyway
#
# Cell In[17], line 5
#       3 total_money = '3'
#       4 try:
# ----> 5     total_money = total_money **2
#       6 except TypeError as e:
#       7     print("Not expecting something that isnt a number!")
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ### Iteration
# Iteration allows us to do something multiple times. This can greatly reduce time spent on manual work if applied to the right problems.
#
# In python, this is done with the `for` keyword, followed by an 'iterable' object  - an object you can iterate over.
# The `range` keyword lets you quickly make a basic iterable

# %%
for i in range(10000):
    print('The current iteration is', i)
# Out:
# The current iteration is 0
# The current iteration is 1
# The current iteration is 2
# The current iteration is 3
# The current iteration is 4
# The current iteration is 5
# The current iteration is 6
# The current iteration is 7
# The current iteration is 8
# The current iteration is 9
# The current iteration is 10
# The current iteration is 11
# The current iteration is 12
# The current iteration is 13
# The current iteration is 14
# The current iteration is 15
# The current iteration is 16
# The current iteration is 17
# The current iteration is 18
# The current iteration is 19
# The current iteration is 20
# The current iteration is 21
# The current iteration is 22
# The current iteration is 23
# The current iteration is 24
# The current iteration is 25
# The current iteration is 26
# The current iteration is 27
# The current iteration is 28
# The current iteration is 29
# The current iteration is 30
# The current iteration is 31
# The current iteration is 32
# The current iteration is 33
# The current iteration is 34
# The current iteration is 35
# The current iteration is 36
# The current iteration is 37
# The current iteration is 38
# The current iteration is 39
# The current iteration is 40
# The current iteration is 41
# The current iteration is 42
# The current iteration is 43
# The current iteration is 44
# The current iteration is 45
# The current iteration is 46
# The current iteration is 47
# The current iteration is 48
# The current iteration is 49
# The current iteration is 50
# The current iteration is 51
# The current iteration is 52
# The current iteration is 53
# The current iteration is 54
# The current iteration is 55
# The current iteration is 56
# The current iteration is 57
# The current iteration is 58
# The current iteration is 59
# The current iteration is 60
# The current iteration is 61
# The current iteration is 62
# The current iteration is 63
# The current iteration is 64
# The current iteration is 65
# The current iteration is 66
# The current iteration is 67
# The current iteration is 68
# The current iteration is 69
# The current iteration is 70
# The current iteration is 71
# The current iteration is 72
# The current iteration is 73
# The current iteration is 74
# The current iteration is 75
# The current iteration is 76
# The current iteration is 77
# The current iteration is 78
# The current iteration is 79
# The current iteration is 80
# The current iteration is 81
# The current iteration is 82
# The current iteration is 83
# The current iteration is 84
# The current iteration is 85
# The current iteration is 86
# The current iteration is 87
# The current iteration is 88
# The current iteration is 89
# The current iteration is 90
# The current iteration is 91
# The current iteration is 92
# The current iteration is 93
# The current iteration is 94
# The current iteration is 95
# The current iteration is 96
# The current iteration is 97
# The current iteration is 98
# The current iteration is 99
# The current iteration is 100
# The current iteration is 101
# The current iteration is 102
# The current iteration is 103
# The current iteration is 104
# The current iteration is 105
# The current iteration is 106
# The current iteration is 107
# The current iteration is 108
# The current iteration is 109
# The current iteration is 110
# The current iteration is 111
# The current iteration is 112
# The current iteration is 113
# The current iteration is 114
# The current iteration is 115
# The current iteration is 116
# The current iteration is 117
# The current iteration is 118
# The current iteration is 119
# The current iteration is 120
# The current iteration is 121
# The current iteration is 122
# The current iteration is 123
# The current iteration is 124
# The current iteration is 125
# The current iteration is 126
# The current iteration is 127
# The current iteration is 128
# The current iteration is 129
# The current iteration is 130
# The current iteration is 131
# The current iteration is 132
# The current iteration is 133
# The current iteration is 134
# The current iteration is 135
# The current iteration is 136
# The current iteration is 137
# The current iteration is 138
# The current iteration is 139
# The current iteration is 140
# The current iteration is 141
# The current iteration is 142
# The current iteration is 143
# The current iteration is 144
# The current iteration is 145
# The current iteration is 146
# The current iteration is 147
# The current iteration is 148
# The current iteration is 149
# The current iteration is 150
# The current iteration is 151
# The current iteration is 152
# The current iteration is 153
# The current iteration is 154
# The current iteration is 155
# The current iteration is 156
# The current iteration is 157
# The current iteration is 158
# The current iteration is 159
# The current iteration is 160
# The current iteration is 161
# The current iteration is 162
# The current iteration is 163
# The current iteration is 164
# The current iteration is 165
# The current iteration is 166
# The current iteration is 167
# The current iteration is 168
# The current iteration is 169
# The current iteration is 170
# The current iteration is 171
# The current iteration is 172
# The current iteration is 173
# The current iteration is 174
# The current iteration is 175
# The current iteration is 176
# The current iteration is 177
# The current iteration is 178
# The current iteration is 179
# The current iteration is 180
# The current iteration is 181
# The current iteration is 182
# The current iteration is 183
# The current iteration is 184
# The current iteration is 185
# The current iteration is 186
# The current iteration is 187
# The current iteration is 188
# The current iteration is 189
# The current iteration is 190
# The current iteration is 191
# The current iteration is 192
# The current iteration is 193
# The current iteration is 194
# The current iteration is 195
# The current iteration is 196
# The current iteration is 197
# The current iteration is 198
# The current iteration is 199
# The current iteration is 200
# The current iteration is 201
# The current iteration is 202
# The current iteration is 203
# The current iteration is 204
# The current iteration is 205
# The current iteration is 206
# The current iteration is 207
# The current iteration is 208
# The current iteration is 209
# The current iteration is 210
# The current iteration is 211
# The current iteration is 212
# The current iteration is 213
# The current iteration is 214
# The current iteration is 215
# The current iteration is 216
# The current iteration is 217
# The current iteration is 218
# The current iteration is 219
# The current iteration is 220
# The current iteration is 221
# The current iteration is 222
# The current iteration is 223
# The current iteration is 224
# The current iteration is 225
# The current iteration is 226
# The current iteration is 227
# The current iteration is 228
# The current iteration is 229
# The current iteration is 230
# The current iteration is 231
# The current iteration is 232
# The current iteration is 233
# The current iteration is 234
# The current iteration is 235
# The current iteration is 236
# The current iteration is 237
# The current iteration is 238
# The current iteration is 239
# The current iteration is 240
# The current iteration is 241
# The current iteration is 242
# The current iteration is 243
# The current iteration is 244
# The current iteration is 245
# The current iteration is 246
# The current iteration is 247
# The current iteration is 248
# The current iteration is 249
# The current iteration is 250
# The current iteration is 251
# The current iteration is 252
# The current iteration is 253
# The current iteration is 254
# The current iteration is 255
# The current iteration is 256
# The current iteration is 257
# The current iteration is 258
# The current iteration is 259
# The current iteration is 260
# The current iteration is 261
# The current iteration is 262
# The current iteration is 263
# The current iteration is 264
# The current iteration is 265
# The current iteration is 266
# The current iteration is 267
# The current iteration is 268
# The current iteration is 269
# The current iteration is 270
# The current iteration is 271
# The current iteration is 272
# The current iteration is 273
# The current iteration is 274
# The current iteration is 275
# The current iteration is 276
# The current iteration is 277
# The current iteration is 278
# The current iteration is 279
# The current iteration is 280
# The current iteration is 281
# The current iteration is 282
# The current iteration is 283
# The current iteration is 284
# The current iteration is 285
# The current iteration is 286
# The current iteration is 287
# The current iteration is 288
# The current iteration is 289
# The current iteration is 290
# The current iteration is 291
# The current iteration is 292
# The current iteration is 293
# The current iteration is 294
# The current iteration is 295
# The current iteration is 296
# The current iteration is 297
# The current iteration is 298
# The current iteration is 299
# The current iteration is 300
# The current iteration is 301
# The current iteration is 302
# The current iteration is 303
# The current iteration is 304
# The current iteration is 305
# The current iteration is 306
# The current iteration is 307
# The current iteration is 308
# The current iteration is 309
# The current iteration is 310
# The current iteration is 311
# The current iteration is 312
# The current iteration is 313
# The current iteration is 314
# The current iteration is 315
# The current iteration is 316
# The current iteration is 317
# The current iteration is 318
# The current iteration is 319
# The current iteration is 320
# The current iteration is 321
# The current iteration is 322
# The current iteration is 323
# The current iteration is 324
# The current iteration is 325
# The current iteration is 326
# The current iteration is 327
# The current iteration is 328
# The current iteration is 329
# The current iteration is 330
# The current iteration is 331
# The current iteration is 332
# The current iteration is 333
# The current iteration is 334
# The current iteration is 335
# The current iteration is 336
# The current iteration is 337
# The current iteration is 338
# The current iteration is 339
# The current iteration is 340
# The current iteration is 341
# The current iteration is 342
# The current iteration is 343
# The current iteration is 344
# The current iteration is 345
# The current iteration is 346
# The current iteration is 347
# The current iteration is 348
# The current iteration is 349
# The current iteration is 350
# The current iteration is 351
# The current iteration is 352
# The current iteration is 353
# The current iteration is 354
# The current iteration is 355
# The current iteration is 356
# The current iteration is 357
# The current iteration is 358
# The current iteration is 359
# The current iteration is 360
# The current iteration is 361
# The current iteration is 362
# The current iteration is 363
# The current iteration is 364
# The current iteration is 365
# The current iteration is 366
# The current iteration is 367
# The current iteration is 368
# The current iteration is 369
# The current iteration is 370
# The current iteration is 371
# The current iteration is 372
# The current iteration is 373
# The current iteration is 374
# The current iteration is 375
# The current iteration is 376
# The current iteration is 377
# The current iteration is 378
# The current iteration is 379
# The current iteration is 380
# The current iteration is 381
# The current iteration is 382
# The current iteration is 383
# The current iteration is 384
# The current iteration is 385
# The current iteration is 386
# The current iteration is 387
# The current iteration is 388
# The current iteration is 389
# The current iteration is 390
# The current iteration is 391
# The current iteration is 392
# The current iteration is 393
# The current iteration is 394
# The current iteration is 395
# The current iteration is 396
# The current iteration is 397
# The current iteration is 398
# The current iteration is 399
# The current iteration is 400
# The current iteration is 401
# The current iteration is 402
# The current iteration is 403
# The current iteration is 404
# The current iteration is 405
# The current iteration is 406
# The current iteration is 407
# The current iteration is 408
# The current iteration is 409
# The current iteration is 410
# The current iteration is 411
# The current iteration is 412
# The current iteration is 413
# The current iteration is 414
# The current iteration is 415
# The current iteration is 416
# The current iteration is 417
# The current iteration is 418
# The current iteration is 419
# The current iteration is 420
# The current iteration is 421
# The current iteration is 422
# The current iteration is 423
# The current iteration is 424
# The current iteration is 425
# The current iteration is 426
# The current iteration is 427
# The current iteration is 428
# The current iteration is 429
# The current iteration is 430
# The current iteration is 431
# The current iteration is 432
# The current iteration is 433
# The current iteration is 434
# The current iteration is 435
# The current iteration is 436
# The current iteration is 437
# The current iteration is 438
# The current iteration is 439
# The current iteration is 440
# The current iteration is 441
# The current iteration is 442
# The current iteration is 443
# The current iteration is 444
# The current iteration is 445
# The current iteration is 446
# The current iteration is 447
# The current iteration is 448
# The current iteration is 449
# The current iteration is 450
# The current iteration is 451
# The current iteration is 452
# The current iteration is 453
# The current iteration is 454
# The current iteration is 455
# The current iteration is 456
# The current iteration is 457
# The current iteration is 458
# The current iteration is 459
# The current iteration is 460
# The current iteration is 461
# The current iteration is 462
# The current iteration is 463
# The current iteration is 464
# The current iteration is 465
# The current iteration is 466
# The current iteration is 467
# The current iteration is 468
# The current iteration is 469
# The current iteration is 470
# The current iteration is 471
# The current iteration is 472
# The current iteration is 473
# The current iteration is 474
# The current iteration is 475
# The current iteration is 476
# The current iteration is 477
# The current iteration is 478
# The current iteration is 479
# The current iteration is 480
# The current iteration is 481
# The current iteration is 482
# The current iteration is 483
# The current iteration is 484
# The current iteration is 485
# The current iteration is 486
# The current iteration is 487
# The current iteration is 488
# The current iteration is 489
# The current iteration is 490
# The current iteration is 491
# The current iteration is 492
# The current iteration is 493
# The current iteration is 494
# The current iteration is 495
# The current iteration is 496
# The current iteration is 497
# The current iteration is 498
# The current iteration is 499
# The current iteration is 500
# The current iteration is 501
# The current iteration is 502
# The current iteration is 503
# The current iteration is 504
# The current iteration is 505
# The current iteration is 506
# The current iteration is 507
# The current iteration is 508
# The current iteration is 509
# The current iteration is 510
# The current iteration is 511
# The current iteration is 512
# The current iteration is 513
# The current iteration is 514
# The current iteration is 515
# The current iteration is 516
# The current iteration is 517
# The current iteration is 518
# The current iteration is 519
# The current iteration is 520
# The current iteration is 521
# The current iteration is 522
# The current iteration is 523
# The current iteration is 524
# The current iteration is 525
# The current iteration is 526
# The current iteration is 527
# The current iteration is 528
# The current iteration is 529
# The current iteration is 530
# The current iteration is 531
# The current iteration is 532
# The current iteration is 533
# The current iteration is 534
# The current iteration is 535
# The current iteration is 536
# The current iteration is 537
# The current iteration is 538
# The current iteration is 539
# The current iteration is 540
# The current iteration is 541
# The current iteration is 542
# The current iteration is 543
# The current iteration is 544
# The current iteration is 545
# The current iteration is 546
# The current iteration is 547
# The current iteration is 548
# The current iteration is 549
# The current iteration is 550
# The current iteration is 551
# The current iteration is 552
# The current iteration is 553
# The current iteration is 554
# The current iteration is 555
# The current iteration is 556
# The current iteration is 557
# The current iteration is 558
# The current iteration is 559
# The current iteration is 560
# The current iteration is 561
# The current iteration is 562
# The current iteration is 563
# The current iteration is 564
# The current iteration is 565
# The current iteration is 566
# The current iteration is 567
# The current iteration is 568
# The current iteration is 569
# The current iteration is 570
# The current iteration is 571
# The current iteration is 572
# The current iteration is 573
# The current iteration is 574
# The current iteration is 575
# The current iteration is 576
# The current iteration is 577
# The current iteration is 578
# The current iteration is 579
# The current iteration is 580
# The current iteration is 581
# The current iteration is 582
# The current iteration is 583
# The current iteration is 584
# The current iteration is 585
# The current iteration is 586
# The current iteration is 587
# The current iteration is 588
# The current iteration is 589
# The current iteration is 590
# The current iteration is 591
# The current iteration is 592
# The current iteration is 593
# The current iteration is 594
# The current iteration is 595
# The current iteration is 596
# The current iteration is 597
# The current iteration is 598
# The current iteration is 599
# The current iteration is 600
# The current iteration is 601
# The current iteration is 602
# The current iteration is 603
# The current iteration is 604
# The current iteration is 605
# The current iteration is 606
# The current iteration is 607
# The current iteration is 608
# The current iteration is 609
# The current iteration is 610
# The current iteration is 611
# The current iteration is 612
# The current iteration is 613
# The current iteration is 614
# The current iteration is 615
# The current iteration is 616
# The current iteration is 617
# The current iteration is 618
# The current iteration is 619
# The current iteration is 620
# The current iteration is 621
# The current iteration is 622
# The current iteration is 623
# The current iteration is 624
# The current iteration is 625
# The current iteration is 626
# The current iteration is 627
# The current iteration is 628
# The current iteration is 629
# The current iteration is 630
# The current iteration is 631
# The current iteration is 632
# The current iteration is 633
# The current iteration is 634
# The current iteration is 635
# The current iteration is 636
# The current iteration is 637
# The current iteration is 638
# The current iteration is 639
# The current iteration is 640
# The current iteration is 641
# The current iteration is 642
# The current iteration is 643
# The current iteration is 644
# The current iteration is 645
# The current iteration is 646
# The current iteration is 647
# The current iteration is 648
# The current iteration is 649
# The current iteration is 650
# The current iteration is 651
# The current iteration is 652
# The current iteration is 653
# The current iteration is 654
# The current iteration is 655
# The current iteration is 656
# The current iteration is 657
# The current iteration is 658
# The current iteration is 659
# The current iteration is 660
# The current iteration is 661
# The current iteration is 662
# The current iteration is 663
# The current iteration is 664
# The current iteration is 665
# The current iteration is 666
# The current iteration is 667
# The current iteration is 668
# The current iteration is 669
# The current iteration is 670
# The current iteration is 671
# The current iteration is 672
# The current iteration is 673
# The current iteration is 674
# The current iteration is 675
# The current iteration is 676
# The current iteration is 677
# The current iteration is 678
# The current iteration is 679
# The current iteration is 680
# The current iteration is 681
# The current iteration is 682
# The current iteration is 683
# The current iteration is 684
# The current iteration is 685
# The current iteration is 686
# The current iteration is 687
# The current iteration is 688
# The current iteration is 689
# The current iteration is 690
# The current iteration is 691
# The current iteration is 692
# The current iteration is 693
# The current iteration is 694
# The current iteration is 695
# The current iteration is 696
# The current iteration is 697
# The current iteration is 698
# The current iteration is 699
# The current iteration is 700
# The current iteration is 701
# The current iteration is 702
# The current iteration is 703
# The current iteration is 704
# The current iteration is 705
# The current iteration is 706
# The current iteration is 707
# The current iteration is 708
# The current iteration is 709
# The current iteration is 710
# The current iteration is 711
# The current iteration is 712
# The current iteration is 713
# The current iteration is 714
# The current iteration is 715
# The current iteration is 716
# The current iteration is 717
# The current iteration is 718
# The current iteration is 719
# The current iteration is 720
# The current iteration is 721
# The current iteration is 722
# The current iteration is 723
# The current iteration is 724
# The current iteration is 725
# The current iteration is 726
# The current iteration is 727
# The current iteration is 728
# The current iteration is 729
# The current iteration is 730
# The current iteration is 731
# The current iteration is 732
# The current iteration is 733
# The current iteration is 734
# The current iteration is 735
# The current iteration is 736
# The current iteration is 737
# The current iteration is 738
# The current iteration is 739
# The current iteration is 740
# The current iteration is 741
# The current iteration is 742
# The current iteration is 743
# The current iteration is 744
# The current iteration is 745
# The current iteration is 746
# The current iteration is 747
# The current iteration is 748
# The current iteration is 749
# The current iteration is 750
# The current iteration is 751
# The current iteration is 752
# The current iteration is 753
# The current iteration is 754
# The current iteration is 755
# The current iteration is 756
# The current iteration is 757
# The current iteration is 758
# The current iteration is 759
# The current iteration is 760
# The current iteration is 761
# The current iteration is 762
# The current iteration is 763
# The current iteration is 764
# The current iteration is 765
# The current iteration is 766
# The current iteration is 767
# The current iteration is 768
# The current iteration is 769
# The current iteration is 770
# The current iteration is 771
# The current iteration is 772
# The current iteration is 773
# The current iteration is 774
# The current iteration is 775
# The current iteration is 776
# The current iteration is 777
# The current iteration is 778
# The current iteration is 779
# The current iteration is 780
# The current iteration is 781
# The current iteration is 782
# The current iteration is 783
# The current iteration is 784
# The current iteration is 785
# The current iteration is 786
# The current iteration is 787
# The current iteration is 788
# The current iteration is 789
# The current iteration is 790
# The current iteration is 791
# The current iteration is 792
# The current iteration is 793
# The current iteration is 794
# The current iteration is 795
# The current iteration is 796
# The current iteration is 797
# The current iteration is 798
# The current iteration is 799
# The current iteration is 800
# The current iteration is 801
# The current iteration is 802
# The current iteration is 803
# The current iteration is 804
# The current iteration is 805
# The current iteration is 806
# The current iteration is 807
# The current iteration is 808
# The current iteration is 809
# The current iteration is 810
# The current iteration is 811
# The current iteration is 812
# The current iteration is 813
# The current iteration is 814
# The current iteration is 815
# The current iteration is 816
# The current iteration is 817
# The current iteration is 818
# The current iteration is 819
# The current iteration is 820
# The current iteration is 821
# The current iteration is 822
# The current iteration is 823
# The current iteration is 824
# The current iteration is 825
# The current iteration is 826
# The current iteration is 827
# The current iteration is 828
# The current iteration is 829
# The current iteration is 830
# The current iteration is 831
# The current iteration is 832
# The current iteration is 833
# The current iteration is 834
# The current iteration is 835
# The current iteration is 836
# The current iteration is 837
# The current iteration is 838
# The current iteration is 839
# The current iteration is 840
# The current iteration is 841
# The current iteration is 842
# The current iteration is 843
# The current iteration is 844
# The current iteration is 845
# The current iteration is 846
# The current iteration is 847
# The current iteration is 848
# The current iteration is 849
# The current iteration is 850
# The current iteration is 851
# The current iteration is 852
# The current iteration is 853
# The current iteration is 854
# The current iteration is 855
# The current iteration is 856
# The current iteration is 857
# The current iteration is 858
# The current iteration is 859
# The current iteration is 860
# The current iteration is 861
# The current iteration is 862
# The current iteration is 863
# The current iteration is 864
# The current iteration is 865
# The current iteration is 866
# The current iteration is 867
# The current iteration is 868
# The current iteration is 869
# The current iteration is 870
# The current iteration is 871
# The current iteration is 872
# The current iteration is 873
# The current iteration is 874
# The current iteration is 875
# The current iteration is 876
# The current iteration is 877
# The current iteration is 878
# The current iteration is 879
# The current iteration is 880
# The current iteration is 881
# The current iteration is 882
# The current iteration is 883
# The current iteration is 884
# The current iteration is 885
# The current iteration is 886
# The current iteration is 887
# The current iteration is 888
# The current iteration is 889
# The current iteration is 890
# The current iteration is 891
# The current iteration is 892
# The current iteration is 893
# The current iteration is 894
# The current iteration is 895
# The current iteration is 896
# The current iteration is 897
# The current iteration is 898
# The current iteration is 899
# The current iteration is 900
# The current iteration is 901
# The current iteration is 902
# The current iteration is 903
# The current iteration is 904
# The current iteration is 905
# The current iteration is 906
# The current iteration is 907
# The current iteration is 908
# The current iteration is 909
# The current iteration is 910
# The current iteration is 911
# The current iteration is 912
# The current iteration is 913
# The current iteration is 914
# The current iteration is 915
# The current iteration is 916
# The current iteration is 917
# The current iteration is 918
# The current iteration is 919
# The current iteration is 920
# The current iteration is 921
# The current iteration is 922
# The current iteration is 923
# The current iteration is 924
# The current iteration is 925
# The current iteration is 926
# The current iteration is 927
# The current iteration is 928
# The current iteration is 929
# The current iteration is 930
# The current iteration is 931
# The current iteration is 932
# The current iteration is 933
# The current iteration is 934
# The current iteration is 935
# The current iteration is 936
# The current iteration is 937
# The current iteration is 938
# The current iteration is 939
# The current iteration is 940
# The current iteration is 941
# The current iteration is 942
# The current iteration is 943
# The current iteration is 944
# The current iteration is 945
# The current iteration is 946
# The current iteration is 947
# The current iteration is 948
# The current iteration is 949
# The current iteration is 950
# The current iteration is 951
# The current iteration is 952
# The current iteration is 953
# The current iteration is 954
# The current iteration is 955
# The current iteration is 956
# The current iteration is 957
# The current iteration is 958
# The current iteration is 959
# The current iteration is 960
# The current iteration is 961
# The current iteration is 962
# The current iteration is 963
# The current iteration is 964
# The current iteration is 965
# The current iteration is 966
# The current iteration is 967
# The current iteration is 968
# The current iteration is 969
# The current iteration is 970
# The current iteration is 971
# The current iteration is 972
# The current iteration is 973
# The current iteration is 974
# The current iteration is 975
# The current iteration is 976
# The current iteration is 977
# The current iteration is 978
# The current iteration is 979
# The current iteration is 980
# The current iteration is 981
# The current iteration is 982
# The current iteration is 983
# The current iteration is 984
# The current iteration is 985
# The current iteration is 986
# The current iteration is 987
# The current iteration is 988
# The current iteration is 989
# The current iteration is 990
# The current iteration is 991
# The current iteration is 992
# The current iteration is 993
# The current iteration is 994
# The current iteration is 995
# The current iteration is 996
# The current iteration is 997
# The current iteration is 998
# The current iteration is 999
# The current iteration is 1000
# The current iteration is 1001
# The current iteration is 1002
# The current iteration is 1003
# The current iteration is 1004
# The current iteration is 1005
# The current iteration is 1006
# The current iteration is 1007
# The current iteration is 1008
# The current iteration is 1009
# The current iteration is 1010
# The current iteration is 1011
# The current iteration is 1012
# The current iteration is 1013
# The current iteration is 1014
# The current iteration is 1015
# The current iteration is 1016
# The current iteration is 1017
# The current iteration is 1018
# The current iteration is 1019
# The current iteration is 1020
# The current iteration is 1021
# The current iteration is 1022
# The current iteration is 1023
# The current iteration is 1024
# The current iteration is 1025
# The current iteration is 1026
# The current iteration is 1027
# The current iteration is 1028
# The current iteration is 1029
# The current iteration is 1030
# The current iteration is 1031
# The current iteration is 1032
# The current iteration is 1033
# The current iteration is 1034
# The current iteration is 1035
# The current iteration is 1036
# The current iteration is 1037
# The current iteration is 1038
# The current iteration is 1039
# The current iteration is 1040
# The current iteration is 1041
# The current iteration is 1042
# The current iteration is 1043
# The current iteration is 1044
# The current iteration is 1045
# The current iteration is 1046
# The current iteration is 1047
# The current iteration is 1048
# The current iteration is 1049
# The current iteration is 1050
# The current iteration is 1051
# The current iteration is 1052
# The current iteration is 1053
# The current iteration is 1054
# The current iteration is 1055
# The current iteration is 1056
# The current iteration is 1057
# The current iteration is 1058
# The current iteration is 1059
# The current iteration is 1060
# The current iteration is 1061
# The current iteration is 1062
# The current iteration is 1063
# The current iteration is 1064
# The current iteration is 1065
# The current iteration is 1066
# The current iteration is 1067
# The current iteration is 1068
# The current iteration is 1069
# The current iteration is 1070
# The current iteration is 1071
# The current iteration is 1072
# The current iteration is 1073
# The current iteration is 1074
# The current iteration is 1075
# The current iteration is 1076
# The current iteration is 1077
# The current iteration is 1078
# The current iteration is 1079
# The current iteration is 1080
# The current iteration is 1081
# The current iteration is 1082
# The current iteration is 1083
# The current iteration is 1084
# The current iteration is 1085
# The current iteration is 1086
# The current iteration is 1087
# The current iteration is 1088
# The current iteration is 1089
# The current iteration is 1090
# The current iteration is 1091
# The current iteration is 1092
# The current iteration is 1093
# The current iteration is 1094
# The current iteration is 1095
# The current iteration is 1096
# The current iteration is 1097
# The current iteration is 1098
# The current iteration is 1099
# The current iteration is 1100
# The current iteration is 1101
# The current iteration is 1102
# The current iteration is 1103
# The current iteration is 1104
# The current iteration is 1105
# The current iteration is 1106
# The current iteration is 1107
# The current iteration is 1108
# The current iteration is 1109
# The current iteration is 1110
# The current iteration is 1111
# The current iteration is 1112
# The current iteration is 1113
# The current iteration is 1114
# The current iteration is 1115
# The current iteration is 1116
# The current iteration is 1117
# The current iteration is 1118
# The current iteration is 1119
# The current iteration is 1120
# The current iteration is 1121
# The current iteration is 1122
# The current iteration is 1123
# The current iteration is 1124
# The current iteration is 1125
# The current iteration is 1126
# The current iteration is 1127
# The current iteration is 1128
# The current iteration is 1129
# The current iteration is 1130
# The current iteration is 1131
# The current iteration is 1132
# The current iteration is 1133
# The current iteration is 1134
# The current iteration is 1135
# The current iteration is 1136
# The current iteration is 1137
# The current iteration is 1138
# The current iteration is 1139
# The current iteration is 1140
# The current iteration is 1141
# The current iteration is 1142
# The current iteration is 1143
# The current iteration is 1144
# The current iteration is 1145
# The current iteration is 1146
# The current iteration is 1147
# The current iteration is 1148
# The current iteration is 1149
# The current iteration is 1150
# The current iteration is 1151
# The current iteration is 1152
# The current iteration is 1153
# The current iteration is 1154
# The current iteration is 1155
# The current iteration is 1156
# The current iteration is 1157
# The current iteration is 1158
# The current iteration is 1159
# The current iteration is 1160
# The current iteration is 1161
# The current iteration is 1162
# The current iteration is 1163
# The current iteration is 1164
# The current iteration is 1165
# The current iteration is 1166
# The current iteration is 1167
# The current iteration is 1168
# The current iteration is 1169
# The current iteration is 1170
# The current iteration is 1171
# The current iteration is 1172
# The current iteration is 1173
# The current iteration is 1174
# The current iteration is 1175
# The current iteration is 1176
# The current iteration is 1177
# The current iteration is 1178
# The current iteration is 1179
# The current iteration is 1180
# The current iteration is 1181
# The current iteration is 1182
# The current iteration is 1183
# The current iteration is 1184
# The current iteration is 1185
# The current iteration is 1186
# The current iteration is 1187
# The current iteration is 1188
# The current iteration is 1189
# The current iteration is 1190
# The current iteration is 1191
# The current iteration is 1192
# The current iteration is 1193
# The current iteration is 1194
# The current iteration is 1195
# The current iteration is 1196
# The current iteration is 1197
# The current iteration is 1198
# The current iteration is 1199
# The current iteration is 1200
# The current iteration is 1201
# The current iteration is 1202
# The current iteration is 1203
# The current iteration is 1204
# The current iteration is 1205
# The current iteration is 1206
# The current iteration is 1207
# The current iteration is 1208
# The current iteration is 1209
# The current iteration is 1210
# The current iteration is 1211
# The current iteration is 1212
# The current iteration is 1213
# The current iteration is 1214
# The current iteration is 1215
# The current iteration is 1216
# The current iteration is 1217
# The current iteration is 1218
# The current iteration is 1219
# The current iteration is 1220
# The current iteration is 1221
# The current iteration is 1222
# The current iteration is 1223
# The current iteration is 1224
# The current iteration is 1225
# The current iteration is 1226
# The current iteration is 1227
# The current iteration is 1228
# The current iteration is 1229
# The current iteration is 1230
# The current iteration is 1231
# The current iteration is 1232
# The current iteration is 1233
# The current iteration is 1234
# The current iteration is 1235
# The current iteration is 1236
# The current iteration is 1237
# The current iteration is 1238
# The current iteration is 1239
# The current iteration is 1240
# The current iteration is 1241
# The current iteration is 1242
# The current iteration is 1243
# The current iteration is 1244
# The current iteration is 1245
# The current iteration is 1246
# The current iteration is 1247
# The current iteration is 1248
# The current iteration is 1249
# The current iteration is 1250
# The current iteration is 1251
# The current iteration is 1252
# The current iteration is 1253
# The current iteration is 1254
# The current iteration is 1255
# The current iteration is 1256
# The current iteration is 1257
# The current iteration is 1258
# The current iteration is 1259
# The current iteration is 1260
# The current iteration is 1261
# The current iteration is 1262
# The current iteration is 1263
# The current iteration is 1264
# The current iteration is 1265
# The current iteration is 1266
# The current iteration is 1267
# The current iteration is 1268
# The current iteration is 1269
# The current iteration is 1270
# The current iteration is 1271
# The current iteration is 1272
# The current iteration is 1273
# The current iteration is 1274
# The current iteration is 1275
# The current iteration is 1276
# The current iteration is 1277
# The current iteration is 1278
# The current iteration is 1279
# The current iteration is 1280
# The current iteration is 1281
# The current iteration is 1282
# The current iteration is 1283
# The current iteration is 1284
# The current iteration is 1285
# The current iteration is 1286
# The current iteration is 1287
# The current iteration is 1288
# The current iteration is 1289
# The current iteration is 1290
# The current iteration is 1291
# The current iteration is 1292
# The current iteration is 1293
# The current iteration is 1294
# The current iteration is 1295
# The current iteration is 1296
# The current iteration is 1297
# The current iteration is 1298
# The current iteration is 1299
# The current iteration is 1300
# The current iteration is 1301
# The current iteration is 1302
# The current iteration is 1303
# The current iteration is 1304
# The current iteration is 1305
# The current iteration is 1306
# The current iteration is 1307
# The current iteration is 1308
# The current iteration is 1309
# The current iteration is 1310
# The current iteration is 1311
# The current iteration is 1312
# The current iteration is 1313
# The current iteration is 1314
# The current iteration is 1315
# The current iteration is 1316
# The current iteration is 1317
# The current iteration is 1318
# The current iteration is 1319
# The current iteration is 1320
# The current iteration is 1321
# The current iteration is 1322
# The current iteration is 1323
# The current iteration is 1324
# The current iteration is 1325
# The current iteration is 1326
# The current iteration is 1327
# The current iteration is 1328
# The current iteration is 1329
# The current iteration is 1330
# The current iteration is 1331
# The current iteration is 1332
# The current iteration is 1333
# The current iteration is 1334
# The current iteration is 1335
# The current iteration is 1336
# The current iteration is 1337
# The current iteration is 1338
# The current iteration is 1339
# The current iteration is 1340
# The current iteration is 1341
# The current iteration is 1342
# The current iteration is 1343
# The current iteration is 1344
# The current iteration is 1345
# The current iteration is 1346
# The current iteration is 1347
# The current iteration is 1348
# The current iteration is 1349
# The current iteration is 1350
# The current iteration is 1351
# The current iteration is 1352
# The current iteration is 1353
# The current iteration is 1354
# The current iteration is 1355
# The current iteration is 1356
# The current iteration is 1357
# The current iteration is 1358
# The current iteration is 1359
# The current iteration is 1360
# The current iteration is 1361
# The current iteration is 1362
# The current iteration is 1363
# The current iteration is 1364
# The current iteration is 1365
# The current iteration is 1366
# The current iteration is 1367
# The current iteration is 1368
# The current iteration is 1369
# The current iteration is 1370
# The current iteration is 1371
# The current iteration is 1372
# The current iteration is 1373
# The current iteration is 1374
# The current iteration is 1375
# The current iteration is 1376
# The current iteration is 1377
# The current iteration is 1378
# The current iteration is 1379
# The current iteration is 1380
# The current iteration is 1381
# The current iteration is 1382
# The current iteration is 1383
# The current iteration is 1384
# The current iteration is 1385
# The current iteration is 1386
# The current iteration is 1387
# The current iteration is 1388
# The current iteration is 1389
# The current iteration is 1390
# The current iteration is 1391
# The current iteration is 1392
# The current iteration is 1393
# The current iteration is 1394
# The current iteration is 1395
# The current iteration is 1396
# The current iteration is 1397
# The current iteration is 1398
# The current iteration is 1399
# The current iteration is 1400
# The current iteration is 1401
# The current iteration is 1402
# The current iteration is 1403
# The current iteration is 1404
# The current iteration is 1405
# The current iteration is 1406
# The current iteration is 1407
# The current iteration is 1408
# The current iteration is 1409
# The current iteration is 1410
# The current iteration is 1411
# The current iteration is 1412
# The current iteration is 1413
# The current iteration is 1414
# The current iteration is 1415
# The current iteration is 1416
# The current iteration is 1417
# The current iteration is 1418
# The current iteration is 1419
# The current iteration is 1420
# The current iteration is 1421
# The current iteration is 1422
# The current iteration is 1423
# The current iteration is 1424
# The current iteration is 1425
# The current iteration is 1426
# The current iteration is 1427
# The current iteration is 1428
# The current iteration is 1429
# The current iteration is 1430
# The current iteration is 1431
# The current iteration is 1432
# The current iteration is 1433
# The current iteration is 1434
# The current iteration is 1435
# The current iteration is 1436
# The current iteration is 1437
# The current iteration is 1438
# The current iteration is 1439
# The current iteration is 1440
# The current iteration is 1441
# The current iteration is 1442
# The current iteration is 1443
# The current iteration is 1444
# The current iteration is 1445
# The current iteration is 1446
# The current iteration is 1447
# The current iteration is 1448
# The current iteration is 1449
# The current iteration is 1450
# The current iteration is 1451
# The current iteration is 1452
# The current iteration is 1453
# The current iteration is 1454
# The current iteration is 1455
# The current iteration is 1456
# The current iteration is 1457
# The current iteration is 1458
# The current iteration is 1459
# The current iteration is 1460
# The current iteration is 1461
# The current iteration is 1462
# The current iteration is 1463
# The current iteration is 1464
# The current iteration is 1465
# The current iteration is 1466
# The current iteration is 1467
# The current iteration is 1468
# The current iteration is 1469
# The current iteration is 1470
# The current iteration is 1471
# The current iteration is 1472
# The current iteration is 1473
# The current iteration is 1474
# The current iteration is 1475
# The current iteration is 1476
# The current iteration is 1477
# The current iteration is 1478
# The current iteration is 1479
# The current iteration is 1480
# The current iteration is 1481
# The current iteration is 1482
# The current iteration is 1483
# The current iteration is 1484
# The current iteration is 1485
# The current iteration is 1486
# The current iteration is 1487
# The current iteration is 1488
# The current iteration is 1489
# The current iteration is 1490
# The current iteration is 1491
# The current iteration is 1492
# The current iteration is 1493
# The current iteration is 1494
# The current iteration is 1495
# The current iteration is 1496
# The current iteration is 1497
# The current iteration is 1498
# The current iteration is 1499
# The current iteration is 1500
# The current iteration is 1501
# The current iteration is 1502
# The current iteration is 1503
# The current iteration is 1504
# The current iteration is 1505
# The current iteration is 1506
# The current iteration is 1507
# The current iteration is 1508
# The current iteration is 1509
# The current iteration is 1510
# The current iteration is 1511
# The current iteration is 1512
# The current iteration is 1513
# The current iteration is 1514
# The current iteration is 1515
# The current iteration is 1516
# The current iteration is 1517
# The current iteration is 1518
# The current iteration is 1519
# The current iteration is 1520
# The current iteration is 1521
# The current iteration is 1522
# The current iteration is 1523
# The current iteration is 1524
# The current iteration is 1525
# The current iteration is 1526
# The current iteration is 1527
# The current iteration is 1528
# The current iteration is 1529
# The current iteration is 1530
# The current iteration is 1531
# The current iteration is 1532
# The current iteration is 1533
# The current iteration is 1534
# The current iteration is 1535
# The current iteration is 1536
# The current iteration is 1537
# The current iteration is 1538
# The current iteration is 1539
# The current iteration is 1540
# The current iteration is 1541
# The current iteration is 1542
# The current iteration is 1543
# The current iteration is 1544
# The current iteration is 1545
# The current iteration is 1546
# The current iteration is 1547
# The current iteration is 1548
# The current iteration is 1549
# The current iteration is 1550
# The current iteration is 1551
# The current iteration is 1552
# The current iteration is 1553
# The current iteration is 1554
# The current iteration is 1555
# The current iteration is 1556
# The current iteration is 1557
# The current iteration is 1558
# The current iteration is 1559
# The current iteration is 1560
# The current iteration is 1561
# The current iteration is 1562
# The current iteration is 1563
# The current iteration is 1564
# The current iteration is 1565
# The current iteration is 1566
# The current iteration is 1567
# The current iteration is 1568
# The current iteration is 1569
# The current iteration is 1570
# The current iteration is 1571
# The current iteration is 1572
# The current iteration is 1573
# The current iteration is 1574
# The current iteration is 1575
# The current iteration is 1576
# The current iteration is 1577
# The current iteration is 1578
# The current iteration is 1579
# The current iteration is 1580
# The current iteration is 1581
# The current iteration is 1582
# The current iteration is 1583
# The current iteration is 1584
# The current iteration is 1585
# The current iteration is 1586
# The current iteration is 1587
# The current iteration is 1588
# The current iteration is 1589
# The current iteration is 1590
# The current iteration is 1591
# The current iteration is 1592
# The current iteration is 1593
# The current iteration is 1594
# The current iteration is 1595
# The current iteration is 1596
# The current iteration is 1597
# The current iteration is 1598
# The current iteration is 1599
# The current iteration is 1600
# The current iteration is 1601
# The current iteration is 1602
# The current iteration is 1603
# The current iteration is 1604
# The current iteration is 1605
# The current iteration is 1606
# The current iteration is 1607
# The current iteration is 1608
# The current iteration is 1609
# The current iteration is 1610
# The current iteration is 1611
# The current iteration is 1612
# The current iteration is 1613
# The current iteration is 1614
# The current iteration is 1615
# The current iteration is 1616
# The current iteration is 1617
# The current iteration is 1618
# The current iteration is 1619
# The current iteration is 1620
# The current iteration is 1621
# The current iteration is 1622
# The current iteration is 1623
# The current iteration is 1624
# The current iteration is 1625
# The current iteration is 1626
# The current iteration is 1627
# The current iteration is 1628
# The current iteration is 1629
# The current iteration is 1630
# The current iteration is 1631
# The current iteration is 1632
# The current iteration is 1633
# The current iteration is 1634
# The current iteration is 1635
# The current iteration is 1636
# ...
# The current iteration is 9467
# The current iteration is 9468
# The current iteration is 9469
# The current iteration is 9470
# The current iteration is 9471
# The current iteration is 9472
# The current iteration is 9473
# The current iteration is 9474
# The current iteration is 9475
# The current iteration is 9476
# The current iteration is 9477
# The current iteration is 9478
# The current iteration is 9479
# The current iteration is 9480
# The current iteration is 9481
# The current iteration is 9482
# The current iteration is 9483
# The current iteration is 9484
# The current iteration is 9485
# The current iteration is 9486
# The current iteration is 9487
# The current iteration is 9488
# The current iteration is 9489
# The current iteration is 9490
# The current iteration is 9491
# The current iteration is 9492
# The current iteration is 9493
# The current iteration is 9494
# The current iteration is 9495
# The current iteration is 9496
# The current iteration is 9497
# The current iteration is 9498
# The current iteration is 9499
# The current iteration is 9500
# The current iteration is 9501
# The current iteration is 9502
# The current iteration is 9503
# The current iteration is 9504
# The current iteration is 9505
# The current iteration is 9506
# The current iteration is 9507
# The current iteration is 9508
# The current iteration is 9509
# The current iteration is 9510
# The current iteration is 9511
# The current iteration is 9512
# The current iteration is 9513
# The current iteration is 9514
# The current iteration is 9515
# The current iteration is 9516
# The current iteration is 9517
# The current iteration is 9518
# The current iteration is 9519
# The current iteration is 9520
# The current iteration is 9521
# The current iteration is 9522
# The current iteration is 9523
# The current iteration is 9524
# The current iteration is 9525
# The current iteration is 9526
# The current iteration is 9527
# The current iteration is 9528
# The current iteration is 9529
# The current iteration is 9530
# The current iteration is 9531
# The current iteration is 9532
# The current iteration is 9533
# The current iteration is 9534
# The current iteration is 9535
# The current iteration is 9536
# The current iteration is 9537
# The current iteration is 9538
# The current iteration is 9539
# The current iteration is 9540
# The current iteration is 9541
# The current iteration is 9542
# The current iteration is 9543
# The current iteration is 9544
# The current iteration is 9545
# The current iteration is 9546
# The current iteration is 9547
# The current iteration is 9548
# The current iteration is 9549
# The current iteration is 9550
# The current iteration is 9551
# The current iteration is 9552
# The current iteration is 9553
# The current iteration is 9554
# The current iteration is 9555
# The current iteration is 9556
# The current iteration is 9557
# The current iteration is 9558
# The current iteration is 9559
# The current iteration is 9560
# The current iteration is 9561
# The current iteration is 9562
# The current iteration is 9563
# The current iteration is 9564
# The current iteration is 9565
# The current iteration is 9566
# The current iteration is 9567
# The current iteration is 9568
# The current iteration is 9569
# The current iteration is 9570
# The current iteration is 9571
# The current iteration is 9572
# The current iteration is 9573
# The current iteration is 9574
# The current iteration is 9575
# The current iteration is 9576
# The current iteration is 9577
# The current iteration is 9578
# The current iteration is 9579
# The current iteration is 9580
# The current iteration is 9581
# The current iteration is 9582
# The current iteration is 9583
# The current iteration is 9584
# The current iteration is 9585
# The current iteration is 9586
# The current iteration is 9587
# The current iteration is 9588
# The current iteration is 9589
# The current iteration is 9590
# The current iteration is 9591
# The current iteration is 9592
# The current iteration is 9593
# The current iteration is 9594
# The current iteration is 9595
# The current iteration is 9596
# The current iteration is 9597
# The current iteration is 9598
# The current iteration is 9599
# The current iteration is 9600
# The current iteration is 9601
# The current iteration is 9602
# The current iteration is 9603
# The current iteration is 9604
# The current iteration is 9605
# The current iteration is 9606
# The current iteration is 9607
# The current iteration is 9608
# The current iteration is 9609
# The current iteration is 9610
# The current iteration is 9611
# The current iteration is 9612
# The current iteration is 9613
# The current iteration is 9614
# The current iteration is 9615
# The current iteration is 9616
# The current iteration is 9617
# The current iteration is 9618
# The current iteration is 9619
# The current iteration is 9620
# The current iteration is 9621
# The current iteration is 9622
# The current iteration is 9623
# The current iteration is 9624
# The current iteration is 9625
# The current iteration is 9626
# The current iteration is 9627
# The current iteration is 9628
# The current iteration is 9629
# The current iteration is 9630
# The current iteration is 9631
# The current iteration is 9632
# The current iteration is 9633
# The current iteration is 9634
# The current iteration is 9635
# The current iteration is 9636
# The current iteration is 9637
# The current iteration is 9638
# The current iteration is 9639
# The current iteration is 9640
# The current iteration is 9641
# The current iteration is 9642
# The current iteration is 9643
# The current iteration is 9644
# The current iteration is 9645
# The current iteration is 9646
# The current iteration is 9647
# The current iteration is 9648
# The current iteration is 9649
# The current iteration is 9650
# The current iteration is 9651
# The current iteration is 9652
# The current iteration is 9653
# The current iteration is 9654
# The current iteration is 9655
# The current iteration is 9656
# The current iteration is 9657
# The current iteration is 9658
# The current iteration is 9659
# The current iteration is 9660
# The current iteration is 9661
# The current iteration is 9662
# The current iteration is 9663
# The current iteration is 9664
# The current iteration is 9665
# The current iteration is 9666
# The current iteration is 9667
# The current iteration is 9668
# The current iteration is 9669
# The current iteration is 9670
# The current iteration is 9671
# The current iteration is 9672
# The current iteration is 9673
# The current iteration is 9674
# The current iteration is 9675
# The current iteration is 9676
# The current iteration is 9677
# The current iteration is 9678
# The current iteration is 9679
# The current iteration is 9680
# The current iteration is 9681
# The current iteration is 9682
# The current iteration is 9683
# The current iteration is 9684
# The current iteration is 9685
# The current iteration is 9686
# The current iteration is 9687
# The current iteration is 9688
# The current iteration is 9689
# The current iteration is 9690
# The current iteration is 9691
# The current iteration is 9692
# The current iteration is 9693
# The current iteration is 9694
# The current iteration is 9695
# The current iteration is 9696
# The current iteration is 9697
# The current iteration is 9698
# The current iteration is 9699
# The current iteration is 9700
# The current iteration is 9701
# The current iteration is 9702
# The current iteration is 9703
# The current iteration is 9704
# The current iteration is 9705
# The current iteration is 9706
# The current iteration is 9707
# The current iteration is 9708
# The current iteration is 9709
# The current iteration is 9710
# The current iteration is 9711
# The current iteration is 9712
# The current iteration is 9713
# The current iteration is 9714
# The current iteration is 9715
# The current iteration is 9716
# The current iteration is 9717
# The current iteration is 9718
# The current iteration is 9719
# The current iteration is 9720
# The current iteration is 9721
# The current iteration is 9722
# The current iteration is 9723
# The current iteration is 9724
# The current iteration is 9725
# The current iteration is 9726
# The current iteration is 9727
# The current iteration is 9728
# The current iteration is 9729
# The current iteration is 9730
# The current iteration is 9731
# The current iteration is 9732
# The current iteration is 9733
# The current iteration is 9734
# The current iteration is 9735
# The current iteration is 9736
# The current iteration is 9737
# The current iteration is 9738
# The current iteration is 9739
# The current iteration is 9740
# The current iteration is 9741
# The current iteration is 9742
# The current iteration is 9743
# The current iteration is 9744
# The current iteration is 9745
# The current iteration is 9746
# The current iteration is 9747
# The current iteration is 9748
# The current iteration is 9749
# The current iteration is 9750
# The current iteration is 9751
# The current iteration is 9752
# The current iteration is 9753
# The current iteration is 9754
# The current iteration is 9755
# The current iteration is 9756
# The current iteration is 9757
# The current iteration is 9758
# The current iteration is 9759
# The current iteration is 9760
# The current iteration is 9761
# The current iteration is 9762
# The current iteration is 9763
# The current iteration is 9764
# The current iteration is 9765
# The current iteration is 9766
# The current iteration is 9767
# The current iteration is 9768
# The current iteration is 9769
# The current iteration is 9770
# The current iteration is 9771
# The current iteration is 9772
# The current iteration is 9773
# The current iteration is 9774
# The current iteration is 9775
# The current iteration is 9776
# The current iteration is 9777
# The current iteration is 9778
# The current iteration is 9779
# The current iteration is 9780
# The current iteration is 9781
# The current iteration is 9782
# The current iteration is 9783
# The current iteration is 9784
# The current iteration is 9785
# The current iteration is 9786
# The current iteration is 9787
# The current iteration is 9788
# The current iteration is 9789
# The current iteration is 9790
# The current iteration is 9791
# The current iteration is 9792
# The current iteration is 9793
# The current iteration is 9794
# The current iteration is 9795
# The current iteration is 9796
# The current iteration is 9797
# The current iteration is 9798
# The current iteration is 9799
# The current iteration is 9800
# The current iteration is 9801
# The current iteration is 9802
# The current iteration is 9803
# The current iteration is 9804
# The current iteration is 9805
# The current iteration is 9806
# The current iteration is 9807
# The current iteration is 9808
# The current iteration is 9809
# The current iteration is 9810
# The current iteration is 9811
# The current iteration is 9812
# The current iteration is 9813
# The current iteration is 9814
# The current iteration is 9815
# The current iteration is 9816
# The current iteration is 9817
# The current iteration is 9818
# The current iteration is 9819
# The current iteration is 9820
# The current iteration is 9821
# The current iteration is 9822
# The current iteration is 9823
# The current iteration is 9824
# The current iteration is 9825
# The current iteration is 9826
# The current iteration is 9827
# The current iteration is 9828
# The current iteration is 9829
# The current iteration is 9830
# The current iteration is 9831
# The current iteration is 9832
# The current iteration is 9833
# The current iteration is 9834
# The current iteration is 9835
# The current iteration is 9836
# The current iteration is 9837
# The current iteration is 9838
# The current iteration is 9839
# The current iteration is 9840
# The current iteration is 9841
# The current iteration is 9842
# The current iteration is 9843
# The current iteration is 9844
# The current iteration is 9845
# The current iteration is 9846
# The current iteration is 9847
# The current iteration is 9848
# The current iteration is 9849
# The current iteration is 9850
# The current iteration is 9851
# The current iteration is 9852
# The current iteration is 9853
# The current iteration is 9854
# The current iteration is 9855
# The current iteration is 9856
# The current iteration is 9857
# The current iteration is 9858
# The current iteration is 9859
# The current iteration is 9860
# The current iteration is 9861
# The current iteration is 9862
# The current iteration is 9863
# The current iteration is 9864
# The current iteration is 9865
# The current iteration is 9866
# The current iteration is 9867
# The current iteration is 9868
# The current iteration is 9869
# The current iteration is 9870
# The current iteration is 9871
# The current iteration is 9872
# The current iteration is 9873
# The current iteration is 9874
# The current iteration is 9875
# The current iteration is 9876
# The current iteration is 9877
# The current iteration is 9878
# The current iteration is 9879
# The current iteration is 9880
# The current iteration is 9881
# The current iteration is 9882
# The current iteration is 9883
# The current iteration is 9884
# The current iteration is 9885
# The current iteration is 9886
# The current iteration is 9887
# The current iteration is 9888
# The current iteration is 9889
# The current iteration is 9890
# The current iteration is 9891
# The current iteration is 9892
# The current iteration is 9893
# The current iteration is 9894
# The current iteration is 9895
# The current iteration is 9896
# The current iteration is 9897
# The current iteration is 9898
# The current iteration is 9899
# The current iteration is 9900
# The current iteration is 9901
# The current iteration is 9902
# The current iteration is 9903
# The current iteration is 9904
# The current iteration is 9905
# The current iteration is 9906
# The current iteration is 9907
# The current iteration is 9908
# The current iteration is 9909
# The current iteration is 9910
# The current iteration is 9911
# The current iteration is 9912
# The current iteration is 9913
# The current iteration is 9914
# The current iteration is 9915
# The current iteration is 9916
# The current iteration is 9917
# The current iteration is 9918
# The current iteration is 9919
# The current iteration is 9920
# The current iteration is 9921
# The current iteration is 9922
# The current iteration is 9923
# The current iteration is 9924
# The current iteration is 9925
# The current iteration is 9926
# The current iteration is 9927
# The current iteration is 9928
# The current iteration is 9929
# The current iteration is 9930
# The current iteration is 9931
# The current iteration is 9932
# The current iteration is 9933
# The current iteration is 9934
# The current iteration is 9935
# The current iteration is 9936
# The current iteration is 9937
# The current iteration is 9938
# The current iteration is 9939
# The current iteration is 9940
# The current iteration is 9941
# The current iteration is 9942
# The current iteration is 9943
# The current iteration is 9944
# The current iteration is 9945
# The current iteration is 9946
# The current iteration is 9947
# The current iteration is 9948
# The current iteration is 9949
# The current iteration is 9950
# The current iteration is 9951
# The current iteration is 9952
# The current iteration is 9953
# The current iteration is 9954
# The current iteration is 9955
# The current iteration is 9956
# The current iteration is 9957
# The current iteration is 9958
# The current iteration is 9959
# The current iteration is 9960
# The current iteration is 9961
# The current iteration is 9962
# The current iteration is 9963
# The current iteration is 9964
# The current iteration is 9965
# The current iteration is 9966
# The current iteration is 9967
# The current iteration is 9968
# The current iteration is 9969
# The current iteration is 9970
# The current iteration is 9971
# The current iteration is 9972
# The current iteration is 9973
# The current iteration is 9974
# The current iteration is 9975
# The current iteration is 9976
# The current iteration is 9977
# The current iteration is 9978
# The current iteration is 9979
# The current iteration is 9980
# The current iteration is 9981
# The current iteration is 9982
# The current iteration is 9983
# The current iteration is 9984
# The current iteration is 9985
# The current iteration is 9986
# The current iteration is 9987
# The current iteration is 9988
# The current iteration is 9989
# The current iteration is 9990
# The current iteration is 9991
# The current iteration is 9992
# The current iteration is 9993
# The current iteration is 9994
# The current iteration is 9995
# The current iteration is 9996
# The current iteration is 9997
# The current iteration is 9998
# The current iteration is 9999

# %%
# Create a list of names of remote sesning missions called 'satellites'

# Loop over the list of satellites, and print out what each one is

# %%
# Create a dictionary of government acronyms

# Loop over a dictionary with the .items, .values, or .keys methods

# %% [markdown]
# ### 🔔 Challenge - house prices
# Write a loop that operates on the variable `house_price_hun_thousands` below. It should
# 1. Take the current value of `house_price_hun_thousands` and multiply by 1.1
# 2. Take that value and add 3
# 3. Do steps 1. and 2. ten times
# 4. Finally, print out the value of `house_price_hun_thousands`. It should be close to 307. NB: Make sure this is un-indented!

# %%
# Staring house price value in hundreads of thousands
house_price_hun_thousands = 500 
savings = 0
savings_per_year = 50
# Write your loop below.
for i in range(10):
    house_price_hun_thousands = house_price_hun_thousands*1.1
    savings += savings_per_year*(1.05)**i
print(house_price_hun_thousands, savings)
# Out:
# 1296.8712300500006 628.8946267774417

# %% [markdown]
# ## Abstraction - Functions and more
# The final programming concept is [abstraction](https://en.wikipedia.org/wiki/Abstraction_(computer_science)) . When combined with the other two concepts, abstraction truly makes programming a force to be reckoned with.
# At a basic level, abstraction is representing a complicated concept in a simpler way at a higher level.
# One level of abstraction is using assembly instructions of a processor rather than dealing with voltages of transistors. Another level is using Python rather than assembly instructions, and so on.
#
# For our purposes, abstraction will involve the creation and use of `functions`, `classes`, and a few other things.
# In this course we will create `functions`, but only use `classes` that other people have already made.
#
# ### 🔔 Challenge - Doctrings/Fix the function
# A [docstring](https://peps.python.org/pep-0257/#what-is-a-docstring) is a string (`str`) of text at the top of a function defined with three quotation marks on either side.
# The goal of a docstring is to summarise the function, and in a way, act as a plain english contract between the developer and the user as to how a function should behave.
# This is just as important when the deveolper and the user are **both you**!
#
#
#
# 📛 The function below has something wrong with it. Read the docstring of the function below and work out is wrong, then fix it and see if the output matches the docstring

# %%
# Creating the function called "append_S2_prefix"
def append_S2_prefix(filename_input):
    """ Adds the S2 prefix to a filename (string), e.g. "art" becomes "S2_MSI_L2a_art" """
    filename_prefix = "S2_MSI_L2a_"
    prefixed_filename = filename_prefix + filename_input
    return filename_prefix

# using the function and printing the output
basic_filename = "grid_32_aug_2023.tif"
print(append_S2_prefix(basic_filename))
# Out:
# S2_MSI_L2a_

# %% [markdown]
# ## 📚 Classes - A quick rundown for this workshop
# In python, a `class` defines a **collection** of both **data** and **functions** grouped together.
# An `instance` of of a class class is then a group of data and functions as defined by that class, often just called an "object"
# A class inherently knows what data belongs to it, and class functions can use both an instance's own data and user supplied input.
#
# In the next notebook, we will use a class from the library `eodag` to download satellite data.
# The benifit of using a class is that we can:
# - Create an object of the `eodag` downloader class
# - Use the object to query the server (the object will remember the output)
# - Have the object download thumbnails for the products
# - Have the object download the products we wish
# And all without having to keep track of variables ourselves (besides the downloader object).
#
# We'll also use other objects, such as a `shapely` `Polygon` (a collection of points representing a 2D area), `numpy` arrays (a collection of numbers), and `xarray` `Dataframes` (a collection of numpy arrays and metadata, repsenting a Geo Image)
#
# 😮‍💨 We wont need to create any classes in this course, so we wont touch on them any more than we have to.
# > NB: functions assigned to a class are generally called "methods"

# %% [markdown]
# ### 🔔 Challenge - Combining everything together
# This challenge will test everything you should know so far by creating and testing a function.
#
# Your function will:
# - Be called `reflectance_modifier`
# - Takes as input a single variable called `reflectance`
# - If the value of `reflectance` input is less than 0, then `raise` a `ValueError` with appropriate dialogue like before (e.g. `raise ValueError("Bad input")`)
# - If the value is a string raise the same error (hint: use the [isinstance()](https://www.w3schools.com/python/ref_func_isinstance.asp) function against `str` type) -
# - 3 times over, sets a new `reflectance` value to be `0.1` plus the old value of `reflectance`, then multipled by the old `reflectance` value
# - After those 3 iterations, add `0.01` to `reflectance`
# - If the value of `reflectance` is greater than 1, it sets the value of `reflectance` to 1.
# - If the value of `reflectance` is less than 0, set the value of `reflectance` to 0.
# - Return the value of `reflectance`
#
# You should then test your function against the following values:
# - `-0.1`
# - `'Perth'`
# - `0.1`
# - `0.8`
# - `15`
#
# The outputs should be:
# - `ValueError`
# - `ValueError`
# - `0.01024576`
# - `0.4176121600000002`
# - `1`

# %%
# Write your functions here. NB: This is not an actual algorithm, just an example

# %%
# Test 1 
reflectance_modifier( # FINISH ME!

# %%
# Test 2

# %%
# Test 3

# %%
# Test 4

# %%
# Test 5

# %% [markdown]
# ## ❗ Notebook Objectives
# - Understand what a notebook is
# - Understand basic python
# - Understand why abstraction is important
# - Understand at a high level what a function and a class are
